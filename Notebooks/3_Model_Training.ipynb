# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv(r"C:\Users\Khande\Desktop\project 2\Customer-Churn-Prediction\data\customer_churn_preprocessed.csv")

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  ...  MonthlyCharges  TotalCharges  Churn
# 0       0              0        1  ...           29.85         29.85      0
# 1       1              0        0  ...           56.95       1889.50      0
# 2       1              0        0  ...           53.85        108.15      1
# 3       1              0        0  ...           42.30       1840.75      0
# 4       0              0        0  ...           70.70        151.65      1
#
# [5 rows x 20 columns]

# %%
x = df.drop('Churn', axis=1)
y = df['Churn']

# %%
print(x.shape, y.shape)
# Out:
# (7043, 19) (7043,)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (5634, 19) (1409, 19) (5634,) (1409,)

# %%
logistic_model = LogisticRegression()
logistic_model.fit(X_train, y_train)
# Out:
# c:\Users\Khande\Desktop\project 2\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred_logistic = logistic_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred_logistic)
print("Logistic Regression Accuracy: ",accuracy)
# Out:
# Logistic Regression Accuracy:  0.7885024840312278

# %%
cm = confusion_matrix(y_test, y_pred_logistic)
print(cm)
# Out:
# [[903 132]
#  [166 208]]

# %%
print(classification_report(y_test, y_pred_logistic))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86      1035
#            1       0.61      0.56      0.58       374
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.71      0.72      1409
# weighted avg       0.78      0.79      0.79      1409

# %%
df.to_csv(
    r"C:\Users\Khande\Desktop\project 2\Customer-Churn-Prediction\data\customer_churn_preprocessed.csv",
    index=False
)

# %%
import joblib

joblib.dump(
    logistic_model,
    r"C:\Users\Khande\Desktop\project 2\Customer-Churn-Prediction\models\logistic_regression_model.pkl"
)
# Out:
# ['C:\\Users\\Khande\\Desktop\\project 2\\Customer-Churn-Prediction\\models\\logistic_regression_model.pkl']

# %%
import joblib

joblib.dump(
    logistic_model,
    r"C:\Users\Khande\Desktop\project 2\Customer-Churn-Prediction\models\logistic_regression_model.pkl"
)

print("Model Saved Successfully!")
# Out:
# Model Saved Successfully!

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decision_tree_model = DecisionTreeClassifier(random_state=42)

# %%
decision_tree_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_dt = decision_tree_model.predict(X_test)

# %%
dt_accuracy = accuracy_score(y_test,y_pred_dt)
print("Decision Tree Accuracy: ",dt_accuracy)
# Out:
# Decision Tree Accuracy:  0.730305180979418

# %%
cm_dt  = confusion_matrix(y_test, y_pred_dt)
print(cm_dt)
# Out:
# [[835 200]
#  [180 194]]

# %%
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81      1035
#            1       0.49      0.52      0.51       374
#
#     accuracy                           0.73      1409
#    macro avg       0.66      0.66      0.66      1409
# weighted avg       0.73      0.73      0.73      1409

# %%
import joblib

joblib.dump(
    decision_tree_model,
    r"C:\Users\Khande\Desktop\project 2\Customer-Churn-Prediction\models\decision_tree_model.pkl"
)
# Out:
# ['C:\\Users\\Khande\\Desktop\\project 2\\Customer-Churn-Prediction\\models\\decision_tree_model.pkl']

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_forest_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42)

# %%
random_forest_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf = random_forest_model.predict(X_test)

# %%
rf_accuracy = accuracy_score(y_test,y_pred_rf)
print("Random Forest Accuracy: ",rf_accuracy)
# Out:
# Random Forest Accuracy:  0.7920511000709723

# %%
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# [[928 107]
#  [186 188]]

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1035
#            1       0.64      0.50      0.56       374
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.70      0.71      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
import joblib

joblib.dump(
    random_forest_model,
    r"C:\Users\Khande\Desktop\project 2\Customer-Churn-Prediction\models\random_forest_model.pkl"
)
# Out:
# ['C:\\Users\\Khande\\Desktop\\project 2\\Customer-Churn-Prediction\\models\\random_forest_model.pkl']

# %%
comparison_df = pd.DataFrame({
    'Model': ['Logistic Regression', 'Decision Tree', 'Random Forest'],
    "accuracy": [accuracy, dt_accuracy, rf_accuracy]
})      
comparison_df.sort_values(by='accuracy', ascending=False, inplace=True)
comparison_df
# Out:
#                  Model  accuracy
# 2        Random Forest  0.792051
# 0  Logistic Regression  0.788502
# 1        Decision Tree  0.730305

# %%
comparison = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Decision Tree",
        "Random Forest"
    ],
    "Accuracy": [
        accuracy,
        dt_accuracy,
        rf_accuracy
    ]
})

comparison = comparison.sort_values(by="Accuracy", ascending=False)

comparison
# Out:
#                  Model  Accuracy
# 2        Random Forest  0.792051
# 0  Logistic Regression  0.788502
# 1        Decision Tree  0.730305

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.bar(comparison["Model"], comparison["Accuracy"])
plt.title("Model Accuracy Comparison")
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.ylim(0.6, 1.0)
plt.show()

# %%
comparison.to_csv(
    r"C:\Users\Khande\Desktop\project 2\Customer-Churn-Prediction\data\model_comparison.csv",
    index=False
)
